# %% [markdown]
# <a href="https://colab.research.google.com/github/ankit-chuahan/Air_bnb_project/blob/main/Airbnb_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Airbnb  is an online marketplace that connects people who want to rent out their homes with people looking for accommodations in specific locales. The company has come a long way since 2007, when its co-founders first came up with the idea to invite paying guests to sleep on an air mattress in their living room....   This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values **bold text**.
#
# # **our task is to Explore and analyse the data to discover key understandings**

# %% [markdown]
# **summary _01**
#
# I just decided to take up the project is because  i like to travel alot. and most of the travelers find out that accomodation is the major problem during trips. and thats why i Take up this project to find out some insight how can people save there money through those platform

# %% [markdown]
# # *The very first step is to import the libraries we are required during the project*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Uploding data frame and reteriving some basic information from it

# %%
air = pd.read_csv("/content/Airbnb NYC 2019.csv")

# %%
air.shape
print("the number of rows in dataframe is:",air.shape[0])
print("the number of rows in dataframe is:",air.shape[1])
# Out:
# the number of rows in dataframe is: 48895
# the number of rows in dataframe is: 16

# %%
air.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'location', 'area', 'latitude',
#        'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
air.info()

#from here we find out there are not null values in some columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %%
air.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# location                          0
# area                              0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
air.describe()
#from describe we can check the mean ,medain ,count etc of a data in a column
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          3.000000           5.000000           0.720000
# 75%          5.000000          24.000000           2.020000
# max       1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         45.000000
# 75%                          2.000000        227.000000
# max                        327.000000        365.000000

# %%
air.head()
# to access the first few rows of the columns by default its 5
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name   location          area  latitude  longitude        room_type  \
# 0         John   Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1     Jennifer  Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2    Elisabeth  Manhattan        Harlem  40.80902  -73.94190     Private room
# 3  LisaRoxanne   Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4        Laura  Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0               1.37
# 3     89               1                270               4.64
# 4     80              10                  9               0.10
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# 2                               1               365
# 3                               1               194
# 4                               1                 0

# %%
air.tail()
# it show us last 5 rows of data frame
# Out:
#              id                                               name   host_id  \
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
#            host_name   location                area  latitude  longitude  \
# 48890        Sabrina   Brooklyn  Bedford-Stuyvesant  40.67853  -73.94995
# 48891        Marisol   Brooklyn            Bushwick  40.70184  -73.93317
# 48892  Ilgar & Aysel  Manhattan              Harlem  40.81475  -73.94867
# 48893            Taz  Manhattan      Hell's Kitchen  40.75751  -73.99112
# 48894     Christophe  Manhattan      Hell's Kitchen  40.76404  -73.98933
#
#              room_type  price  minimum_nights  number_of_reviews  \
# 48890     Private room     70               2                  0
# 48891     Private room     40               4                  0
# 48892  Entire home/apt    115              10                  0
# 48893      Shared room     55               1                  0
# 48894     Private room     90               7                  0
#
#        reviews_per_month  calculated_host_listings_count  availability_365
# 48890               1.37                               2                 9
# 48891               1.37                               2                36
# 48892               1.37                               1                27
# 48893               1.37                               6                 2
# 48894               1.37                               1                23

# %% [markdown]
# # **Data cleaning Dropping null values or columns which we dont use in EDA**

# %%
air.drop(["last_review"] ,axis=1 ,inplace=True)
# here i drop the column last_review because i dont need it for anaylisis

# %%
air.rename( columns={"neighbourhood_group" :"location","neighbourhood":"area",} ,inplace=True)  #renaming some columns

# %%
mean_of =air["reviews_per_month"].mean().round(2)
mean_of
air["reviews_per_month"].fillna(mean_of,inplace=True)

#here i am filling the missing values with the mean values

# %%
air.dropna(inplace=True)
# here we drop all the null values now data is clean

# %% [markdown]
# # **Exploratory data analysis (EDA)**

# %%
air["room_type"].unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
air.head(2)
# Out:
#      id                                name  host_id host_name   location  \
# 0  2539  Clean & quiet apt home by the park     2787      John   Brooklyn
# 1  2595               Skylit Midtown Castle     2845  Jennifer  Manhattan
#
#          area  latitude  longitude        room_type  price  minimum_nights  \
# 0  Kensington  40.64749  -73.97237     Private room    149               1
# 1     Midtown  40.75362  -73.98377  Entire home/apt    225               1
#
#    number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# 0                  9               0.21                               6
# 1                 45               0.38                               2
#
#    availability_365
# 0               365
# 1               355

# %% [markdown]
# # **Location and price**

# %%
# listing according to location
gen = sns.countplot( x="location",data = air)
gen.bar_label(gen.containers[0])
plt.show()

# %% [markdown]
# ***The most number of properties are located at manhattan and brooklyn***

# %%
# location according to the type of rooms avilable



gen = sns.countplot( x="location",data = air,hue="room_type")
gen.bar_label(gen.containers[0])
for p in gen.containers:
    gen.bar_label(p,label_type='edge')
plt.show()

# %% [markdown]
# ***In every location people prefer private room but in manhattann they prefer entire apartment***

# %%
# effect of location on price

neighbour_ = air.groupby(["location"],as_index = False)["price"].mean().sort_values("price",ascending=False)
sns.barplot(x=neighbour_.location ,y=neighbour_.price )
plt.show()

# %% [markdown]
# ***From the about data we can see that prices in manhatten is more then other places***

# %%
# distribution of location according to mimimum nights

nn = air.groupby("location")[["minimum_nights"]].mean()
ex= [0,0,0.1,0,0]
col = ["#d45087","#f95d6a","#a05195","#665191","#7CDDDD"]
plt.pie(nn['minimum_nights'],labels=nn.index, colors =col,autopct='%1.1f%%',explode=ex,radius=1.2,wedgeprops={"linewidth":1,"edgecolor": 'r'})      #here i use nn.index because after using group by function column on which we make group become index
plt.show()

# %% [markdown]
# ***Even the price of manhatten is higher then other places still people spends most nights in manhatten***

# %% [markdown]
# **summery number o1**
#
# from the above analysis we can say that most of the properties are located in brooklyn and manhatten and people prefer private room over entire appartment but only in manhatten they prefer entire appartment.even the price of manhatten property is higher still every 3rd person spend there night in manhatten

# %% [markdown]
# # ***Latitude and longitute ***

# %%
# Longitude and latitude impact

plt.scatter(air['latitude'] ,air['longitude'],marker="*", )
plt.xlabel("Latitude of the Area")
plt.ylabel("longitude of the area")
plt.title("Distribution of area on basis of longitude and latitude")
plt.show()

# %% [markdown]
# summery number 02
#
# * we can say that most of the people prefer places from 40.6 to 40.8 latitude and -73.8 to 74 longitude *

# %% [markdown]
# # ***Effect of price on reviews***

# %%
room_type = air.groupby(["room_type"],as_index = False)["price"].median().sort_values("price",ascending=False)
room_type
sns.barplot(x="room_type" ,y="price" ,data=room_type )
plt.show()

# %% [markdown]
# # **EFFECt of prices on the per night cost**

# %%
price_review = air[['minimum_nights', 'price']].sort_values(by= 'price')

price_review.plot(x = 'price', y = 'minimum_nights',  kind = 'area', title = 'minimum_nights vs Price', xlim=0,ylim=0)
plt.show()

# %%
unique_counts = air[["host_name"]].apply(lambda row: row.nunique(), axis=1)
len(unique_counts)
# Out:
# 43389

# %%
air.groupby("host_name").agg{}

# %% [markdown]
# From the above data we can say that most of people like to spend nights there nights prices are below 20000

# %%
room_type_stats = air.groupby('room_type').agg({'price': ['mean', 'max', ],"availability_365": ['mean', 'max', ]})
room_type_stats
# Out:
#                       price          availability_365
#                        mean      max             mean    max
# room_type
# Entire home/apt  206.913977  10000.0       105.471392  365.0
# Private room      88.846392  10000.0       105.853447  365.0
# Shared room       71.871822   1800.0       148.497881  365.0

# %%
sns.boxplot(data=air, x='location',y='availability_365',palette="deep")
plt.show()

# %%
corr = air.corr(method='kendall')
plt.figure(figsize=(13,10))
plt.title("Correlation Between Different Variables\n")
sns.heatmap(corr, annot=True)
plt.show()
# Out:
# <ipython-input-80-93c5fa1435ef>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = air.corr(method='kendall')
